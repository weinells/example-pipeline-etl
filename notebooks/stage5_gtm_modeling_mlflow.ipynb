# %% [markdown]
# # Stage 5: GTM + Model Training + MLflow
#
# This notebook builds GTM data, trains four classifiers with stratified 4-fold cross-validation, selects the best model by precision, and logs outputs with MLflow.

# %%
from pathlib import Path

import pandas as pd

# %%
project_root = Path.cwd().parents[1] if Path.cwd().name == 'notebooks' else Path.cwd().parent
script_path = project_root / 'example-pipeline-etl' / 'scripts' / 'modeling' / 'stage5_train_and_track.py'
print('Run this script to execute Stage 5 end-to-end:')
print(script_path)

# %%
# Optional from notebook:
# !python ../scripts/modeling/stage5_train_and_track.py
